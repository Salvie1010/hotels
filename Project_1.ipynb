# %% [markdown]
# ###    hey there!

# %% [markdown]
# ***I honestly wish you the best. I want you to know you can do this. You will excel in this field.***
# ### AND NO!
# You won't stop halfway. You will definitely get through with this. You are smart, persistent and confident. You are good to go! (;

# %% [markdown]
# ## Data summary

# %% [markdown]
# This file contains all the meta information regarding the columns described in the CSV files. we have provided 5 CSV files:
# 1. dim_date
# 2. dim_hotels
# 3. dim_rooms
# 4. fact_aggregated_bookings
# 5. fact_bookings
#
#
# Column Description for dim_date:
# 1. date: This column represents the dates present in May, June and July.
# 2. mmm yy: This column represents the date in the format of mmm yy (monthname year).
# 3. week no: This column represents the unique week number for that particular date.
# 4. day_type: This column represents whether the given day is Weekend or Weekeday.
#
#
#
# Column Description for dim_hotels:
# 1. property_id: This column represents the Unique ID for each of the hotels.
# 2. property_name: This column represents the name of each hotel.
# 3. category: This column determines which class[Luxury, Business] a particular hotel/property belongs to.
# 4. city: This column represents where the particular hotel/property resides in.
#
#
#
# Column Description for dim_rooms:
# 1. room_id: This column represents the type of room[RT1, RT2, RT3, RT4] in a hotel.
# 2. room_class: This column represents to which class[Standard, Elite, Premium, Presidential] particular room type belongs.
#
#
# Column Description for fact_aggregated_bookings:
# 1. property_id: This column represents the Unique ID for each of the hotels.
# 2. check_in_date: This column represents all the check_in_dates of the customers.
# 3. room_category: This column represents the type of room[RT1, RT2, RT3, RT4] in a hotel.
# 4. successful_bookings: This column represents all the successful room bookings that happen for a particular room type in that hotel on that particular date.
# 5. capacity: This column represents the maximum count of rooms available for a particular room type in that hotel on that particular date.
#
#
#
# Column Description for fact_bookings:
# 1. booking_id: This column represents the Unique Booking ID for each customer when they booked their rooms.
# 2. property_id: This column represents the Unique ID for each of the hotels
# 3. booking_date: This column represents the date on which the customer booked their rooms.
# 4. check_in_date: This column represents the date on which the customer check-in(entered) at the hotel.
# 5. check_out_date: This column represents the date on which the customer check-out(left) of the hotel.
# 6. no_guests: This column represents the number of guests who stayed in a particular room in that hotel.
# 7. room_category: This column represents the type of room[RT1, RT2, RT3, RT4] in a hotel.
# 8. booking_platform: This column represents in which way the customer booked his room.
# 9. ratings_given: This column represents the ratings given by the customer for hotel services.
# 10. booking_status: This column represents whether the customer cancelled his booking[Cancelled], successfully stayed in the hotel[Checked Out] or booked his room but not stayed in the hotel[No show].
# 11. revenue_generated: This column represents the amount of money generated by the hotel from a particular customer.
# 12. revenue_realized: This column represents the final amount of money that goes to the hotel based on booking status. If the booking status is cancelled, then 40% of the revenue generated is deducted and the remainin

# %% [markdown]
# ### Questions
#
#
#   1. Which day/week/month booked  the most Presidential bookings
#   2. Which day were all the rooms booked (check successful bookings)
#   3. Which hotels are the best selling and least selling
#   4. Which rooms have the highest bookings in each hotel
#   5. The booking platform best for executive rooms
#   6. The hotels with the highest ratings
#   7. Hotels with the highest revenues
#   8. Relationship btwn executive rooms and revenue
#   9. Which hotel category makes more money
#   10. Which city has th best hotels
#   10. Hotels that exist in multiple cities
#   12. Capacity of hotel brands in each city

# %% [markdown]
# ###  1. Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7eb60341-4f1f-405b-a6e1-c418b0682d86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eb60341-4f1f-405b-a6e1-c418b0682d86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dates=pd.read_csv('dim_date.csv')
hotels=pd.read_csv('dim_hotels.csv')
rooms=pd.read_csv('dim_rooms.csv')
fact_aggregated_bookings=pd.read_csv('fact_aggregated_bookings.csv')
fact_bookings=pd.read_csv('fact_bookings.csv')

# %%
dates
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
hotels
# Out:
#     property_id  property_name  category          city
# 0         16558   CLIFE Grands    Luxury         Abuja
# 1         16559  CLIFE Exotica    Luxury         Lagos
# 2         16560     CLIFE City  Business         Abuja
# 3         16561      CLIFE Blu    Luxury         Abuja
# 4         16562      CLIFE Bay    Luxury         Abuja
# 5         16563   CLIFE Palace  Business         Abuja
# 6         17558   CLIFE Grands    Luxury         Lagos
# 7         17559  CLIFE Exotica    Luxury         Lagos
# 8         17560     CLIFE City  Business         Lagos
# 9         17561      CLIFE Blu    Luxury         Lagos
# 10        17562      CLIFE Bay    Luxury         Lagos
# 11        17563   CLIFE Palace  Business         Lagos
# 12        18558   CLIFE Grands    Luxury  Port Hacourt
# 13        18559  CLIFE Exotica    Luxury  Port Hacourt
# 14        18560     CLIFE City  Business  Port Hacourt
# 15        18561      CLIFE Blu    Luxury  Port Hacourt
# ...

# %%
rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
fact_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559     01-May-22           RT1                   25        30
# 1           19562     01-May-22           RT1                   28        30
# 2           19563     01-May-22           RT1                   23        30
# 3           17558     01-May-22           RT1                   13        19
# 4           16558     01-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
fact_aggregated_bookings.property_id.value_counts()
# Out:
# 16559    368
# 17559    368
# 17564    368
# 19561    368
# 19559    368
# 18563    368
# 18562    368
# 18561    368
# 18559    368
# 18558    368
# 17563    368
# 17562    368
# 16563    368
# 19562    368
# 16562    368
# 16561    368
# 16560    368
# 17561    368
# 19560    368
# 19558    368
# 17560    368
# 16558    368
# 17558    368
# 19563    368
# 18560    368
# Name: property_id, dtype: int64

# %%
fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %%
fact_bookings.property_id.value_counts()
# Out:
# 16559    7338
# 18562    7333
# 16563    7147
# 18560    6638
# 18561    6458
# 17563    6337
# 17559    6142
# 17560    6013
# 19560    5979
# 19562    5812
# 19561    5736
# 19563    5413
# 18559    5256
# 17561    5183
# 17558    5036
# 16562    4820
# 18563    4728
# 19559    4705
# 16560    4693
# 18558    4475
# 16561    4418
# 19558    4371
# 17564    3982
# 17562    3424
# 16558    3153
# Name: property_id, dtype: int64

# %% [markdown]
# ##  Data Assessing
# Here, i will be  visually & programmatic assessing the data. And writing each observation after each assessment

# %%
dates.sample(10)
# Out:
#          date  mmm yy week no  day_type
# 83  23-Jul-22  Jul 22    W 30   weekend
# 17  18-May-22  May 22    W 21  weekeday
# 64  04-Jul-22  Jul 22    W 28  weekeday
# 53  23-Jun-22  Jun 22    W 26  weekeday
# 41  11-Jun-22  Jun 22    W 24   weekend
# 47  17-Jun-22  Jun 22    W 25  weekeday
# 77  17-Jul-22  Jul 22    W 30   weekend
# 55  25-Jun-22  Jun 22    W 26   weekend
# 0   01-May-22  May 22    W 19   weekend
# 3   04-May-22  May 22    W 19  weekeday

# %% [markdown]
#  - Untidy data in date and mmm yy + Rubbish column names
#  - wrong format for the `week no` column
#  - wrong spelling od weekday
#  - Data Repition in two columns

# %%
dates.day_type.value_counts()
# Out:
# weekeday    65
# weekend     27
# Name: day_type, dtype: int64

# %%
dates.isna().sum()
# Out:
# date        0
# mmm yy      0
# week no     0
# day_type    0
# dtype: int64

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
hotels.sample(20)
# Out:
#     property_id  property_name  category          city
# 6         17558   CLIFE Grands    Luxury         Lagos
# 21        19561      CLIFE Blu    Luxury       Calabar
# 24        17564  CLIFE Seasons  Business         Lagos
# 12        18558   CLIFE Grands    Luxury  Port Hacourt
# 9         17561      CLIFE Blu    Luxury         Lagos
# 14        18560     CLIFE City  Business  Port Hacourt
# 7         17559  CLIFE Exotica    Luxury         Lagos
# 4         16562      CLIFE Bay    Luxury         Abuja
# 18        19558   CLIFE Grands    Luxury       Calabar
# 22        19562      CLIFE Bay    Luxury       Calabar
# 16        18562      CLIFE Bay    Luxury  Port Hacourt
# 10        17562      CLIFE Bay    Luxury         Lagos
# 8         17560     CLIFE City  Business         Lagos
# 20        19560     CLIFE City  Business       Calabar
# 0         16558   CLIFE Grands    Luxury         Abuja
# 11        17563   CLIFE Palace  Business         Lagos
# ...

# %% [markdown]
#  - CLIFE in front of all hotel names

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    25 non-null     int64
#  1   property_name  25 non-null     object
#  2   category       25 non-null     object
#  3   city           25 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 928.0+ bytes

# %%
fact_aggregated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 359.5+ KB

# %%
fact_aggregated_bookings.sample(10)
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 1536        19558     16-May-22           RT2                   13        39
# 6922        19559     09-Jul-22           RT1                   18        24
# 1325        19562     14-May-22           RT2                   19        23
# 7965        17564     19-Jul-22           RT3                    8        24
# 8875        17562     28-Jul-22           RT4                    2         6
# 8589        18559     25-Jul-22           RT4                    7        19
# 9082        18561     30-Jul-22           RT4                    6         9
# 2642        17562     27-May-22           RT2                   13        30
# 1154        17558     12-May-22           RT3                   12        27
# 3908        19560     09-Jun-22           RT1                   15        26

# %%
fact_bookings.isna().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77907
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558   2022-04-27    2022-05-01
# 1        May012216558RT12        16558   2022-04-30    2022-05-01
# 2        May012216558RT13        16558   2022-04-28    2022-05-01
# 3        May012216558RT14        16558   2022-04-28    2022-05-01
# 4        May012216558RT15        16558   2022-04-27    2022-05-01
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134586   Jul312217564RT47        17564   2022-07-30    2022-07-31
# 134587   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134588   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134589  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0         2022-05-02          3           RT1    direct online            1.0
# ...

# %% [markdown]
#    - room_category needs to be changed back to the actual types
#      - date format is different compared to the ones in other dataframes
#       - missing values in the ratings_given

# %%
fact_bookings.sample(11)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 10783   May072219562RT214        19562   2022-05-07    2022-05-07
# 87131   Jun292217558RT311        17558   2022-06-24    2022-06-29
# 1356    May012218562RT315        18562   2022-04-27    2022-05-01
# 129949   Jul282219560RT33        19560   2022-07-26    2022-07-28
# 74034    Jun192218562RT16        18562   2022-06-13    2022-06-19
# 52201   Jun052218561RT115        18561   2022-06-03    2022-06-05
# 12977   May082217564RT410        17564   2022-04-14    2022-05-08
# 49358    Jun042216558RT23        16558   2022-06-02    2022-06-04
# 102538  Jul092217560RT126        17560   2022-07-07    2022-07-09
# 8688    May062219559RT311        19559   2022-04-29    2022-05-06
# 63538    Jun122219558RT36        19558   2022-06-06    2022-06-12
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 10783     2022-05-09          2           RT2           others            5.0
# ...

# %%
# new_df = fact_bookings.merge(fact_aggregated_bookings, how='left',on=['property_id','room_category']  )
# new_df

# %% [markdown]
# Summary of assessment
#
#  ### Quality issues
#
#  `Dates`
#  - wrong format for the `week no` column
#  - wrong spelling od weekday
#  - Data Repition in two columns
#  - wrong data type
#
#
#  `Hotels`
#  - CLIFE in front of all hotel names
#
#
#   `Fact_bookings`
#
#
#   - room_category needs to be changed back to the actual types
#   - date format is different compared to the ones in other dataframes
#    - wrong data type for date columns

# %% [markdown]
#  ### Tidiness issues (Two features in one row or column & incomplete data )
#   `Dates`
#    - Untidy data in date and mmm yy + Rubbish column names
#
#
#   `Fact_bookings`
#   - missing values in the ratings_given

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### `1. Quality issues`

# %% [markdown]
# ### Fact_bookings
#      Problem: room_category needs to be changed back to the actual types
#      Solution: Create a dictionary and map the data to the room types

# %% [markdown]
# ### Code

# %%
fact_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
range (0,len(rooms))
# Out:
# range(0, 4)

# %%
for i in range (0,len(rooms)):
  fact_bookings.loc[fact_bookings.room_category==rooms.room_id[i],'room']= rooms.room_class[i]

# %%
### Test

# %%
fact_bookings.room.value_counts()
# Out:
# Elite           49505
# Standard        38446
# Premium         30566
# Presidential    16073
# Name: room, dtype: int64

# %% [markdown]
# Create a new column called ***period of stay***

# %%
fact_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134590 non-null  int64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
#  12  room               134590 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 13.3+ MB

# %%
dates
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
dates['mmm yy'].value_counts()
# Out:
# May 22    31
# Jul 22    31
# Jun 22    30
# Name: mmm yy, dtype: int64

# %%
fact_bookings['booking_date'].min()
# Out:
# '2022-04-07'

# %%
dates.describe()
# Out:
#              date  mmm yy week no  day_type
# count          92      92      92        92
# unique         92       3      14         2
# top     01-May-22  May 22    W 19  weekeday
# freq            1      31       7        65

# %%
fact_bookings.booking_date.nunique()
# Out:
# 116

# %%
fact_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134590.000000   56683.000000      134590.000000
# mean    18061.113493       2.036808       3.619004       14916.013188
# std      1093.055847       1.031766       1.235009        6452.868072
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
fact_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558   2022-04-27    2022-05-01    2022-05-02
# 1  May012216558RT12        16558   2022-04-30    2022-05-01    2022-05-02
# 2  May012216558RT13        16558   2022-04-28    2022-05-01    2022-05-04
# 3  May012216558RT14        16558   2022-04-28    2022-05-01    2022-05-02
# 4  May012216558RT15        16558   2022-04-27    2022-05-01    2022-05-02
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0          3           RT1    direct online            1.0    Checked Out
# 1          2           RT1           others            NaN      Cancelled
# 2          2           RT1          logtrip            5.0    Checked Out
# 3          2           RT1           others            NaN      Cancelled
# 4          4           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized      room
# ...

# %%
hotels.head(6)
# Out:
#    property_id  property_name  category   city
# 0        16558   CLIFE Grands    Luxury  Abuja
# 1        16559  CLIFE Exotica    Luxury  Lagos
# 2        16560     CLIFE City  Business  Abuja
# 3        16561      CLIFE Blu    Luxury  Abuja
# 4        16562      CLIFE Bay    Luxury  Abuja
# 5        16563   CLIFE Palace  Business  Abuja

# %%
for i in range (0,len(hotels)):
  fact_bookings.loc[fact_bookings.property_id==hotels.property_id[i],'property_name']= hotels.property_name[i]
  fact_bookings.loc[fact_bookings.property_id==hotels.property_id[i],'category']= hotels.category[i]
  fact_bookings.loc[fact_bookings.property_id==hotels.property_id[i],'city']= hotels.city[i]

# %%
hotels.category.value_counts()
# Out:
# Luxury      16
# Business     9
# Name: category, dtype: int64

# %%
# df1['value']=df1[['time_by_hour','id']].merge(df2,how='left').value

# %%
# successful_bookings: This column represents all the successful room bookings that happen for a particular room type in that hotel on that particular date.
# 5. capacity: This column represents the maximum count of rooms available for a particular room type in that hotel on that particular date.

# %%
fact_aggregated_bookings.rename(columns={"check_in_date": "date"}, inplace=True)

# %%
fact_aggregated_bookings=fact_aggregated_bookings.merge(dates, how='left', on='date')

# %%
fact_aggregated_bookings.sample(3)
# Out:
#       property_id       date room_category  successful_bookings  capacity  \
# 347         17560  04-May-22           RT2                   20        45
# 3473        18559  04-Jun-22           RT3                   11        23
# 2411        16561  25-May-22           RT1                   12        18
#
#       mmm yy week no  day_type
# 347   May 22    W 19  weekeday
# 3473  Jun 22    W 23   weekend
# 2411  May 22    W 22  weekeday

# %%
# for i in range (0,len(dates)):
#   fact_bookings.loc[fact_bookings.room_category==rooms.room_id[i],'room']= rooms.room_class[i]

# %%
fact_aggregated_bookings=fact_aggregated_bookings.merge(dates, how='left', on='date')

# %%
import datetime

# %%
fact_bookings['booking_date'] = pd.to_datetime(fact_bookings['booking_date'])

# %%
fact_bookings['check_in_date'] = pd.to_datetime(fact_bookings['check_in_date'])
fact_bookings['checkout_date'] = pd.to_datetime(fact_bookings['checkout_date'])

fact_aggregated_bookings['date'] = pd.to_datetime(fact_aggregated_bookings['date'])

# %%
fact_aggregated_bookings.head(1)
# Out:
#    property_id       date room_category  successful_bookings  capacity  \
# 0        16559 2022-05-01           RT1                   25        30
#
#   mmm yy_x week no_x day_type_x mmm yy_y week no_y day_type_y
# 0   May 22      W 19    weekend   May 22      W 19    weekend

# %%
fact_bookings.sample(3)
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 74130   Jun192218563RT115        18563   2022-06-17    2022-06-19
# 30059   May212217563RT224        17563   2022-05-20    2022-05-21
# 122286   Jul232216558RT31        16558   2022-07-19    2022-07-23
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 74130     2022-06-20          1           RT1    direct online            NaN
# 30059     2022-05-22          1           RT2          logtrip            5.0
# 122286    2022-07-25          2           RT3     makeyourtrip            NaN
#
#        booking_status  revenue_generated  revenue_realized      room  \
# 74130     Checked Out               6500              6500  Standard
# 30059     Checked Out              15300             15300     Elite
# 122286    Checked Out              16800             16800   Premium
#
#        property_name  category          city
# 74130   CLIFE Palace  Business  Port Hacourt
# ...

# %%
# fact_bookingz=fact_bookings.merge(fact_aggregated_bookings, how='left', on=['property_id'])

# %%
fact_bookings.shape
# Out:
# (134590, 16)

# %%
fact_bookingz=fact_bookings.join(fact_aggregated_bookings, how='left', on=['property_id','room_category'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-725237b1c5ba> in <module>
# ----> 1 fact_bookingz=fact_bookings.join(fact_aggregated_bookings, how='left', on=['property_id','room_category'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
#    9132                 other,
#
# ...
